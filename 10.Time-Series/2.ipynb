# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\pandas\adv_dataset\AAPL Data.csv', parse_dates=['Date'], index_col = 'Date')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13696\570682069.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv(r'C:\Users\HP\Desktop\pandas\adv_dataset\AAPL Data.csv', parse_dates=['Date'], index_col = 'Date')
#                        Open    High     Low   Close    Volume
# Date
# 2019-10-24 16:00:00   61.13   61.20   60.45   60.90  17916255
# 2019-10-25 16:00:00   60.79   61.68   60.72   61.65  18369296
# 2019-10-28 16:00:00   61.86   62.31   61.68   62.26  24143241
# 2019-10-29 16:00:00   62.24   62.44   60.64   60.82  35709867
# 2019-10-30 16:00:00   61.19   61.33   60.30   60.82  31130522
# ...                     ...     ...     ...     ...       ...
# 2021-10-18 16:00:00  143.45  146.84  143.16  146.55  85589175
# 2021-10-19 16:00:00  147.01  149.17  146.55  148.76  76378894
# 2021-10-20 16:00:00  148.70  149.75  148.12  149.26  58418788
# ...

# %%
# Jan month
df.loc['2020-01'].Close.mean()
# Out:
# np.float64(77.97952380952381)

# %%
# Feb month
df.loc['2020-02'].Close.mean()
# Out:
# np.float64(77.81842105263158)

# %%
df.loc['2020-01'].Close.sum()
# Out:
# np.float64(1637.5700000000002)

# %%
df.loc['2020-01-15'][['Open','Close']]
# Out:
#                       Open  Close
# Date
# 2020-01-15 16:00:00  77.96  77.83

# %%
# find monthly avg of stock price               M, D, W, Q, B, H
df.Close.resample('ME').mean()
# Out:
# Date
# 2019-10-31     61.440000
# 2019-11-30     65.630500
# 2019-12-31     69.132381
# 2020-01-31     77.979524
# 2020-02-29     77.818421
# 2020-03-31     65.611364
# 2020-04-30     68.096667
# 2020-05-31     77.497000
# 2020-06-30     86.452727
# 2020-07-31     95.563636
# 2020-08-31    117.300952
# 2020-09-30    115.125238
# 2020-10-31    116.413182
# 2020-11-30    116.826000
# 2020-12-31    127.290455
# 2021-01-31    133.036842
# 2021-02-28    131.531579
# 2021-03-31    121.871304
# 2021-04-30    131.812857
# 2021-05-31    126.784000
# 2021-06-30    129.958636
# 2021-07-31    145.139524
# 2021-08-31    148.177727
# 2021-09-30    148.306190
# 2021-10-31    144.228750
# Freq: ME, Name: Close, dtype: float64

# %%
# Quaterly
df.Close.resample('Q').mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13696\1138638691.py:2: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean()
# Date
# 2019-12-31     66.660213
# 2020-03-31     73.541452
# 2020-06-30     77.490952
# 2020-09-30    109.114844
# 2020-12-31    120.281250
# 2021-03-31    128.358033
# 2021-06-30    129.568889
# 2021-09-30    147.222969
# 2021-12-31    144.228750
# Freq: QE-DEC, Name: Close, dtype: float64

# %%
# line plot
# %matplotlib inline
obj = df.Close.resample('ME').mean()
obj.plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
# bar plot
# %matplotlib inline
obj = df.Close.resample('ME').mean()
obj.plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>
